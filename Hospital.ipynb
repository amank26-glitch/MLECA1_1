# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score,accuracy_score, confusion_matrix

# %% [markdown]
# Here we import all basic required lib
#
#
# ---

# %%
df = pd.read_csv("/content/hospital_readmissions_30k.csv")

# %% [markdown]
# Loading dataset

# %%
df.head(10).T
# Out:
#                                       0                 1       2       3  \
# patient_id                            1                 2       3       4
# age                                  74                46      89      84
# gender                            Other            Female   Other  Female
# blood_pressure                   130/72            120/92  135/78  123/80
# cholesterol                         240               292     153     153
# bmi                                31.5              36.3    30.3    31.5
# diabetes                            Yes                No      No      No
# hypertension                         No                No     Yes     Yes
# medication_count                      5                 4       1       3
# length_of_stay                        1                 3       1      10
# discharge_destination  Nursing_Facility  Nursing_Facility    Home    Home
# readmitted_30_days                  Yes                No      No      No
#
# ...

# %% [markdown]
# Displaying first 10 rows of data

# %%
df.shape
# Out:
# (30000, 12)

# %% [markdown]
# Checking shape of dataset

# %%
df.columns
# Out:
# Index(['patient_id', 'age', 'gender', 'blood_pressure', 'cholesterol', 'bmi',
#        'diabetes', 'hypertension', 'medication_count', 'length_of_stay',
#        'discharge_destination', 'readmitted_30_days'],
#       dtype='object')

# %%
df.dtypes
# Out:
# patient_id                 int64
# age                        int64
# gender                    object
# blood_pressure            object
# cholesterol                int64
# bmi                      float64
# diabetes                  object
# hypertension              object
# medication_count           int64
# length_of_stay             int64
# discharge_destination     object
# readmitted_30_days        object
# dtype: object

# %% [markdown]
# Checking data type of every variableṁ in dataset

# %%
df.isnull().sum()
print(df.isnull().sum())
# Out:
# patient_id               0
# age                      0
# gender                   0
# blood_pressure           0
# cholesterol              0
# bmi                      0
# diabetes                 0
# hypertension             0
# medication_count         0
# length_of_stay           0
# discharge_destination    0
# readmitted_30_days       0
# dtype: int64

# %% [markdown]
# Checking for null or missing values

# %%
X = df.drop("readmitted_30_days", axis=1)
Y = df["readmitted_30_days"]
print(X.head())
print(Y.head())
# Out:
#    patient_id  age  gender blood_pressure  cholesterol   bmi diabetes  \
# 0           1   74   Other         130/72          240  31.5      Yes
# 1           2   46  Female         120/92          292  36.3       No
# 2           3   89   Other         135/78          153  30.3       No
# 3           4   84  Female         123/80          153  31.5       No
# 4           5   32   Other         135/84          205  18.4       No
#
#   hypertension  medication_count  length_of_stay discharge_destination
# 0           No                 5               1      Nursing_Facility
# 1           No                 4               3      Nursing_Facility
# 2          Yes                 1               1                  Home
# 3          Yes                 3              10                  Home
# 4          Yes                 6               4      Nursing_Facility
# 0    Yes
# 1     No
# 2     No
# 3     No
# 4     No
# Name: readmitted_30_days, dtype: object

# %% [markdown]
# Separating the input and output with a target column

# %%
X = pd.get_dummies(X, drop_first=True)
print(X.head())
# Out:
#    patient_id  age  cholesterol   bmi  medication_count  length_of_stay  \
# 0           1   74          240  31.5                 5               1
# 1           2   46          292  36.3                 4               3
# 2           3   89          153  30.3                 1               1
# 3           4   84          153  31.5                 3              10
# 4           5   32          205  18.4                 6               4
#
#    gender_Male  gender_Other  blood_pressure_110/70  blood_pressure_110/71  \
# 0        False          True                  False                  False
# 1        False         False                  False                  False
# 2        False          True                  False                  False
# 3        False         False                  False                  False
# 4        False          True                  False                  False
#
#    ...  blood_pressure_160/94  blood_pressure_160/95  blood_pressure_160/96  \
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model = LogisticRegression(penalty="l2", max_iter=5000)

# %%
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=5000)

# %%
Y_prob = model.predict_proba(X_test)[:, 1]

# %%
Y_pred = model.predict(X_test)

# %%
auc = roc_auc_score(Y_test, Y_prob)
print("AUC:", auc)
# Out:
# AUC: 0.5803550853059396

# %% [markdown]
# accuracy = accuracy_score(Y_test, Y_pred)
# print("Accuracy:", accuracy)

# %%
accuracy = accuracy_score(Y_test, Y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8718333333333333

# %%
print("\nConfussion Matrix:")
print(confusion_matrix(Y_test, Y_pred))
# Out:
# Confussion Matrix:
# [[5231    0]
#  [ 769    0]]
